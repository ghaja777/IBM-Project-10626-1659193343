# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
salary_df = pd.read_csv('/content/Salary_Data.csv')

# %%
salary_df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
salary_df.dtypes
# Out:
# YearsExperience    float64
# Salary             float64
# dtype: object

# %%
x = np.array(salary_df['YearsExperience'])

# %%
type(x)
# Out:
# numpy.ndarray

# %%
x
# Out:
# array([ 1.1,  1.3,  1.5,  2. ,  2.2,  2.9,  3. ,  3.2,  3.2,  3.7,  3.9,
#         4. ,  4. ,  4.1,  4.5,  4.9,  5.1,  5.3,  5.9,  6. ,  6.8,  7.1,
#         7.9,  8.2,  8.7,  9. ,  9.5,  9.6, 10.3, 10.5])

# %%
y = salary_df['Salary'].values
type(y)
# Out:
# numpy.ndarray

# %%
y
# Out:
# array([ 39343.,  46205.,  37731.,  43525.,  39891.,  56642.,  60150.,
#         54445.,  64445.,  57189.,  63218.,  55794.,  56957.,  57081.,
#         61111.,  67938.,  66029.,  83088.,  81363.,  93940.,  91738.,
#         98273., 101302., 113812., 109431., 105582., 116969., 112635.,
#        122391., 121872.])

# %%
print(x.shape)
print(y.shape)
# Out:
# (30,)
# (30,)

# %%
x = x.reshape(-1,1)
y = y.reshape(-1,1)

# %%
print(x.shape)
print(y.shape)
# Out:
# (30, 1)
# (30, 1)

# %%
x
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %%
y
# Out:
# array([[ 39343.],
#        [ 46205.],
#        [ 37731.],
#        [ 43525.],
#        [ 39891.],
#        [ 56642.],
#        [ 60150.],
#        [ 54445.],
#        [ 64445.],
#        [ 57189.],
#        [ 63218.],
#        [ 55794.],
#        [ 56957.],
#        [ 57081.],
#        [ 61111.],
#        [ 67938.],
#        [ 66029.],
#        [ 83088.],
#        [ 81363.],
#        [ 93940.],
#        [ 91738.],
#        [ 98273.],
#        [101302.],
#        [113812.],
#        [109431.],
#        [105582.],
#        [116969.],
#        [112635.],
#        [122391.],
#        [121872.]])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 2022)

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (24, 1)
# (24, 1)

# %%
print(x_test.shape)
print(y_test.shape)
# Out:
# (6, 1)
# (6, 1)

# %%
x_train
# Out:
# array([[ 2.9],
#        [ 7.1],
#        [ 1.5],
#        [ 6. ],
#        [ 3.9],
#        [ 4.9],
#        [ 8.7],
#        [ 3. ],
#        [ 2. ],
#        [ 1.1],
#        [ 7.9],
#        [ 3.2],
#        [ 4. ],
#        [ 1.3],
#        [ 3.7],
#        [ 8.2],
#        [ 5.9],
#        [ 9.5],
#        [ 9. ],
#        [ 5.3],
#        [ 5.1],
#        [ 4.1],
#        [10.3],
#        [10.5]])

# %%
x_test
# Out:
# array([[3.2],
#        [4. ],
#        [2.2],
#        [4.5],
#        [6.8],
#        [9.6]])

# %%
y_train
# Out:
# array([[ 56642.],
#        [ 98273.],
#        [ 37731.],
#        [ 93940.],
#        [ 63218.],
#        [ 67938.],
#        [109431.],
#        [ 60150.],
#        [ 43525.],
#        [ 39343.],
#        [101302.],
#        [ 64445.],
#        [ 55794.],
#        [ 46205.],
#        [ 57189.],
#        [113812.],
#        [ 81363.],
#        [116969.],
#        [105582.],
#        [ 83088.],
#        [ 66029.],
#        [ 57081.],
#        [122391.],
#        [121872.]])

# %%
y_test
# Out:
# array([[ 54445.],
#        [ 56957.],
#        [ 39891.],
#        [ 61111.],
#        [ 91738.],
#        [112635.]])

# %%
from sklearn.linear_model import LinearRegression 
regressor = LinearRegression()

# %%
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
regressor.coef_
# Out:
# array([[9316.25714449]])

# %%
regressor.intercept_
# Out:
# array([27524.34177691])

# %%
y_pred = regressor.predict(x_test)

# %%
for i in range(0,len(y_pred)):
    print("Predicted: ",y_pred[i]," and Actual: ",y_test[i])
# Out:
# Predicted:  [57336.36463929]  and Actual:  [54445.]
# Predicted:  [64789.37035488]  and Actual:  [56957.]
# Predicted:  [48020.10749479]  and Actual:  [39891.]
# Predicted:  [69447.49892713]  and Actual:  [61111.]
# Predicted:  [90874.89035947]  and Actual:  [91738.]
# Predicted:  [116960.41036405]  and Actual:  [112635.]

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.xlabel('Years of Experience')
plt.ylabel('Salary in INR')
# Out:
# Text(0, 0.5, 'Salary in INR')

# %%
import matplotlib.pyplot as plt
plt.plot(x,regressor.predict(x))
plt.xlabel('Years of Experience')
plt.ylabel('Predicted Salary in INR')
# Out:
# Text(0, 0.5, 'Predicted Salary in INR')

# %%
regressor.score(x,y)*100
# Out:
# 95.53281828831585
